# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("housing.csv")

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data.dropna(inplace=True) # we are deleting all the NaN values for a smooth dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
from sklearn.model_selection import train_test_split # Splitting the data into training and testing data

X = data.drop(['median_house_value'], axis = 1) # x is the input, hence we drop the target variable
y = data['median_house_value'] # y will be the target variable

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)  # Specifying the split percentage

# %%
train_data = X_train.join(y_train) # Combining the I/O for the training data

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2386     -119.49     37.10                24.0       2532.0           555.0
# 8377     -118.35     33.95                30.0       2661.0           765.0
# 3934     -118.57     34.22                27.0       2795.0           606.0
# 3368     -120.20     40.26                26.0       2399.0           518.0
# 19565    -120.95     37.61                17.0       4054.0           654.0
# ...          ...       ...                 ...          ...             ...
# 2777     -115.73     33.36                19.0        749.0           238.0
# 19082    -122.48     38.31                19.0       2398.0           521.0
# 3406     -118.30     34.26                28.0       1643.0           489.0
# 16736    -122.32     37.69                48.0        592.0           122.0
# 915      -121.97     37.52                26.0       3761.0           623.0
#
# ...

# %%
train_data.hist(figsize = (15, 8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(), annot=True, cmap="YlGnBu")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 2
#       1 plt.figure(figsize=(15,8))
# ----> 2 sns.heatmap(train_data.corr(), annot=True, cmap="YlGnBu")
#
# File ~/Desktop/pythonpractice/venv/lib/python3.11/site-packages/pandas/core/frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~/Desktop/pythonpractice/venv/lib/python3.11/site-packages/pandas/core/frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
# ...

# %%
# Data Pre-Processing

#In order to normalize the left-skewed graphs, take the log and add 1 to prevent any 0 values

train_data['total_rooms'] = np.log(train_data['total_rooms'] + 1)
train_data['total_bedrooms'] = np.log(train_data['total_bedrooms'] + 1)
train_data['population'] = np.log(train_data['population'] + 1)
train_data['households'] = np.log(train_data['households'] + 1)

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
# We have an feature that is non-numerical, namely, ocean proximity

train_data.ocean_proximity.value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     7245
# INLAND        5203
# NEAR OCEAN    2081
# NEAR BAY      1812
# ISLAND           5
# Name: count, dtype: int64

# %%
# Since it affects the target, we turn each of its types into a feature and then give it a boolean value 

train_data = train_data.join(pd.get_dummies(train_data.ocean_proximity)).drop(['ocean_proximity'], axis = 1)

# %%
train_data = train_data.drop(['ISLAND'], axis=1)

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
# Visualizing the relation between latitudes/longitudes and the median house value

plt.figure(figsize=(15,8))
sns.scatterplot(x='latitude', y='longitude', data=train_data, hue='median_house_value', palette='coolwarm')
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
train_data['pop_per_hhold'] = train_data['population']/train_data['households']
train_data['rooms_per_pop'] = train_data['total_rooms']/train_data['population']
train_data['bedrooms_per_pop'] = train_data['total_bedrooms']/train_data['population']

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train, y_train = train_data.drop(['median_house_value'], axis=1), train_data['median_house_value']
X_train_s = scaler.fit_transform(X_train)


reg = LinearRegression()

reg.fit(X_train_s, y_train)
# Out:
# LinearRegression()

# %%
test_data = X_test.join(y_test) # Combining the I/O for the testing data

# %%
test_data['total_rooms'] = np.log(test_data['total_rooms'] + 1)
test_data['total_bedrooms'] = np.log(test_data['total_bedrooms'] + 1)
test_data['population'] = np.log(test_data['population'] + 1)
test_data['households'] = np.log(test_data['households'] + 1)

test_data = test_data.join(pd.get_dummies(test_data.ocean_proximity)).drop(['ocean_proximity'], axis=1)


test_data['pop_per_hhold'] = test_data['population']/test_data['households']
test_data['rooms_per_pop'] = test_data['total_rooms']/test_data['population']
test_data['bedrooms_per_pop'] = test_data['total_bedrooms']/test_data['population']

# %%
test_data = test_data.drop(['ISLAND'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 test_data = test_data.drop(['ISLAND'], axis=1)
#
# File ~/Desktop/pythonpractice/venv/lib/python3.11/site-packages/pandas/core/frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
# ...

# %%
X_test, y_test = test_data.drop(['median_house_value'], axis=1), test_data['median_house_value']

# %%
X_test_s = scaler.transform(X_test)

# %%
reg.score(X_test_s, y_test)  # Scaling did not change the performance much
# Out:
# 0.6699362955124601

# %%
from sklearn.ensemble import RandomForestRegressor

forest = RandomForestRegressor()

forest.fit(X_train_s, y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(X_test_s, y_test) # Better than Linear Regression
# Out:
# 0.8135852345163892

# %%
from sklearn.model_selection import GridSearchCV

forest = RandomForestRegressor()

param_grid = {
    "n_estimators": [3, 10, 30],
    "max_features": [2, 4, 6, 8]
}

grid_search = GridSearchCV(forest, param_grid, cv=5, 
                           scoring="neg_mean_squared_error",
                           return_train_score=True)

grid_search.fit(X_train_s, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_features': [2, 4, 6, 8],
#                          'n_estimators': [3, 10, 30]},
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
best_forest = grid_search.best_estimator_

# %%
best_forest.score(X_test_s, y_test)
# Out:
# 0.8067271592030386

# %%
X_matrix = np.array(X_train)

# %%
y_vec = np.array(y_train)

# %%
X_transpose = np.transpose(X_matrix)

# %%
X_T_X = np.matmul(X_transpose, X_matrix)

# %%
X_T_X_inv = np.linalg.inv(X_T_X)
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 X_T_X_inv = np.linalg.inv(X_T_X)
#
# File <__array_function__ internals>:200, in inv(*args, **kwargs)
#
# File ~/Desktop/pythonpractice/venv/lib/python3.11/site-packages/numpy/linalg/linalg.py:538, in inv(a)
#     536 signature = 'D->D' if isComplexType(t) else 'd->d'
#     537 extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 538 ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     539 return wrap(ainv.astype(result_t, copy=False))
#
# UFuncTypeError: Cannot cast ufunc 'inv' input from dtype('O') to dtype('float64') with casting rule 'same_kind'
